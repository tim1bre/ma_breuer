# %% [markdown]
# # Einlesen der Daten

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from Code.S01_Experimente.Monte_Carlo.process_hdf5 import plot_from_exp_id

plt.rcParams['figure.figsize'] = [13, 10] # Größe der Figure festsetzen

# %%
path = r"C:\Users\timbr\OneDrive\Masterarbeit\Daten\2020_08_13_Monte_Carlo_neue_Metriken\\"

# ersten Teil der Monte-Carlo-Studie einlesen
h5_filename1 = "2020_08_13__10_47_27_Monte_Carlo_Data.hdf5"
filename1 = "2020_08_13__10_47_27_Monte_Carlo_DataFrame.pkl"
df_raw1 = pd.read_pickle(path+filename1)

# DTW Daten einlesen
h5_filename2 = "2020_08_17__19_22_16_Monte_Carlo_Data.hdf5" 
filename2 = "2020_08_17__19_22_16_Monte_Carlo_DataFrame.pkl"
df_raw2 = pd.read_pickle(path+filename2)

# change exp_id so that there are no doubles
df_raw2.exp_id = df_raw2.exp_id + df_raw1.exp_id.max()

# DUMMY Daten einlesen
h5_filename3 = "2020_08_20__10_41_43_Monte_Carlo_Data.hdf5" 
filename3 = "2020_08_20__10_41_43_Monte_Carlo_DataFrame.pkl"
df_raw3 = pd.read_pickle(path+filename3)

# change exp_id so that there are no doubles
df_raw3.exp_id = df_raw3.exp_id + df_raw2.exp_id.max()


df_raw = pd.concat([df_raw1, df_raw2, df_raw3])
df_raw['signal_power'] = df_raw['signal_power1'] + df_raw['signal_power2']

# %%
numeric_columns = ['dist_id', 'resloss_sum', 'yexceed+5%', 'resloss_dist', 'signal_power', 'resloss_new1', 'resloss_new2']

for i in numeric_columns:
    df_raw[i] = df_raw[i].apply(pd.to_numeric, errors='coerce')

print(df_raw.shape)
# Out:
# (3174, 43)

# %%
for i in df_raw2.exp_id:
    plot_from_exp_id(path, h5_filename2, i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-5e21abbcff8a> in <module>
#       1 for i in df_raw2.exp_id:
# ----> 2     plot_from_exp_id(path, h5_filename2, i)
#
# ~\OneDrive\Masterarbeit\Repo\ma_breuer\Code\S01_Experimente\Monte_Carlo\process_hdf5.py in plot_from_exp_id(path, filename, exp_id)
#      59     with h5py.File(path+filename, 'r') as hdf:
#      60
# ---> 61         dist1 = hdf['experiments/exp' + str(exp_id)].attrs['dist_name'][0]
#      62         dist2 = hdf['experiments/exp' + str(exp_id)].attrs['dist_name'][1]
#      63         te = hdf['experiments/exp' + str(exp_id) +'/data/t'][()][0][-1]
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~\anaconda3\lib\site-packages\h5py\_hl\group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5o.pyx in h5py.h5o.open()
#
# KeyError: "Unable to open object (object 'exp2117' doesn't exist)"

# %% [markdown]
# # Auswertung der Experimente:
# - Güte der Störerkennung
# - Filterung ungültiger Experimente
# - Störitendsität für Erkennung
# - Messrauschen
# - Modelqualität
# - Totzeit

# %% [markdown]
# # Güte der Störerkennung
# Auswertung hinsichtlich Anzahl an ``False Positive`` und ``False Negative``.

# %%
def determine_detection_quality(df):
    """ determine if two disturbances lead to fp or fn"""
    
    dist_types = ['cosinus', 'noisycos', 'sq_cos', 'chirp', 'ampcos', 'triag', 'random'] # verschiedene Störarten
    
    # init dataframe
    data = {'dist_types': dist_types, 'fp1': [0]*len(dist_types), 'fp2': [0]*len(dist_types),'fn1': [0]*len(dist_types),'fn2': [0]*len(dist_types), 'tp1': [0]*len(dist_types),'tp2': [0]*len(dist_types),}
    df_disttype = pd.DataFrame(data=data)
    
    for dist_type in dist_types:
        for idx, row in df.iterrows():

            # check if current disturbance is disturbance in simulation
            if (dist_type in row.dist_name1):
                if row.fp_dist1 >= 1:
                    df_disttype.loc[df_disttype['dist_types'] == dist_type, ['fp1']] += 1 #row.fp_dist1

            if dist_type in row.dist_name2:
                if row.fp_dist2 >= 1:
                    df_disttype.loc[df_disttype['dist_types'] == dist_type, ['fp2']] += 1 #row.fp_dist2

            if (dist_type in row.dist_name1):
                if row.fn_dist1 >= 1:
                    df_disttype.loc[df_disttype['dist_types'] == dist_type, ['fn1']] += 1 #row.fp_dist1

            if dist_type in row.dist_name2:
                if row.fn_dist2 >= 1:
                    df_disttype.loc[df_disttype['dist_types'] == dist_type, ['fn2']] += 1 #row.fp_dist2

            if dist_type in row.dist_name1:
                if row.fp_dist1 == 0:
                    df_disttype.loc[df_disttype['dist_types'] == dist_type, ['tp1']] += 1

            if dist_type in row.dist_name2:
                if row.fp_dist2 == 0:
                    df_disttype.loc[df_disttype['dist_types'] == dist_type, ['tp2']] += 1
                    
    return df_disttype

# %%
df_disttype = determine_detection_quality(df_raw)
df_disttype_gradient = determine_detection_quality(df_raw[df_raw['detect_mode']=='gradient algo'])
df_disttype_dtw = determine_detection_quality(df_raw[df_raw['detect_mode']=='dtw mean algo'])
df_disttype_model_algo = determine_detection_quality(df_raw[df_raw['detect_mode']=='model algo full'])
df_disttype_ar = determine_detection_quality(df_raw[df_raw['detect_mode']=='model ar l'])
df_disttype_arima = determine_detection_quality(df_raw[df_raw['detect_mode']=='model arima l'])

# %% [markdown]
# ## Güte der Störerkennung mit Unterscheidung in verschiedene Störklassen

# %%
df_disttype
# Out:
#   dist_types  fp1  fp2  fn1  fn2  tp1  tp2
# 0    cosinus   73   93    0    0  272  252
# 1   noisycos   80   99    0    1  265  246
# 2     sq_cos  229  223    1    1    1    7
# 3      chirp  104   96    0    0  241  249
# 4     ampcos   81   91   78   39  264  254
# 5      triag   73   63   98  110  272  282
# 6     random  147  152  296  286  543  538

# %% [markdown]
# ## Aufgeschlüsselt nach Methoden

# %%
df_disttype_gradient
# Out:
#   dist_types  fp1  fp2  fn1  fn2  tp1  tp2
# 0    cosinus    0   13    0    0   69   56
# 1   noisycos    1   15    0    0   68   54
# 2     sq_cos   46   40    0    0    0    6
# 3      chirp   24   34    0    0   45   35
# 4     ampcos    0   12   67   32   69   57
# 5      triag   45   47   23   21   24   22
# 6     random   59   74  114   89   79   64

# %%
df_disttype_dtw
# Out:
#   dist_types  fp1  fp2  fn1  fn2  tp1  tp2
# 0    cosinus   69   69    0    0    0    0
# 1   noisycos   69   69    0    0    0    0
# 2     sq_cos   45   45    1    1    1    1
# 3      chirp   59   46    0    0   10   23
# 4     ampcos   60   66   10    7    9    3
# 5      triag    6    5   45   54   63   64
# 6     random   47   51  117  122   91   87

# %%
df_disttype_model_algo
# Out:
#   dist_types  fp1  fp2  fn1  fn2  tp1  tp2
# 0    cosinus    4    3    0    0   65   66
# 1   noisycos    4    2    0    0   65   67
# 2     sq_cos   46   46    0    0    0    0
# 3      chirp    4    2    0    0   65   67
# 4     ampcos    4    2    0    0   65   67
# 5      triag    6    2    9   11   63   67
# 6     random   14    4   20   29  124  134

# %%
df_disttype_ar
# Out:
#   dist_types  fp1  fp2  fn1  fn2  tp1  tp2
# 0    cosinus    0    3    0    0   69   66
# 1   noisycos    2    8    0    0   67   61
# 2     sq_cos   46   46    0    0    0    0
# 3      chirp    7   11    0    0   62   58
# 4     ampcos   13    4    0    0   56   65
# 5      triag   10    6    5   15   59   63
# 6     random   13   13   24   23  125  125

# %%
df_disttype_arima
# Out:
#   dist_types  fp1  fp2  fn1  fn2  tp1  tp2
# 0    cosinus    0    5    0    0   69   64
# 1   noisycos    4    5    0    1   65   64
# 2     sq_cos   46   46    0    0    0    0
# 3      chirp   10    3    0    0   59   66
# 4     ampcos    4    7    1    0   65   62
# 5      triag    6    3   16    9   63   66
# 6     random   14   10   21   23  124  128

# %%
df_raw2.signal_power
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 524    NaN
# 525    NaN
# 526    NaN
# 527    NaN
# 528    NaN
# Name: signal_power, Length: 529, dtype: object

# %% [markdown]
# # False Negative eher bei schwachen Störungen

# %%
df_raw[df_raw['false_neg_count']>0].signal_power.mean()
# Out:
# 0.4445430662258047

# %%
df_raw[df_raw['false_neg_count']>0].signal_power.median()
# Out:
# 0.42837333998999955

# %%
df_raw.signal_power.mean()
# Out:
# 0.5586152040163811

# %%
df_raw.signal_power.median()
# Out:
# 0.5694656890706353

# %% [markdown]
# Fand eine Anpassung der Sollgröße aufgrund eines ``False Positive`` kurz vor der tatsächlichen Störung statt, so sind die Metriken, wie ``res loss``, nicht mehr aussagekräftigt. Im Folgenden werden diese aussortiert.

# %% [markdown]
# # Auswahl der zubetrachteten Experimente

# %%
df = df_raw[df_raw['disq']==0]

# %% [markdown]
# ## Vergleich über alle Experimente gemittelt

# %%
df['r/s'] = df['resloss_sum'] / df['signal_power']
df_dmod = df[['detect_mode', 'resloss_sum', 'yexceed+5%', 'signal_power', 'r/s']].groupby(['detect_mode']).mean()
df_dmod['count'] = df[['detect_mode', 'resloss_sum']].groupby(['detect_mode']).count()

df_dmod
# Out:
# C:\Users\timbr\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                  resloss_sum  yexceed+5%  signal_power          r/s  count
# detect_mode
# detect_dummy      784.912148    0.000000      0.558705  1500.800749    529
# dtw mean algo     521.950953  122.545089      0.558432  1056.505876    507
# gradient algo     422.770420  185.724051      0.559891   894.369800    436
# model algo full   409.457839   81.257526      0.560912   829.403140    501
# model ar l        414.475827  340.567941      0.558539   842.393695    515
# model arima l     368.395982  466.848550      0.559354   752.043405    493

# %% [markdown]
# # Vergleich der Methoden bei gleicher Störung
#
# Im folgenden Teil wird verglichen, wie die Methoden auf die gleiche Störung reagieren.

# %%
# Liste mit allen Störungen
dist_list = [i for i in range(1, df['dist_id'].max())]

# DatFrame der zählt wie oft eine Methode bei einer bestimmten Störung als beste abgeschnitten hat

df_best = pd.DataFrame(columns=['resloss_sum', 'max_loss1', 'max_loss2', 'time_to_recover1', 'time_to_recover2'])

for idx in df.detect_mode.unique():
    for col in df_best.columns:
        df_best.loc[idx, col] = 0

# %%
for i in dist_list:
    
    df_dist = df[df['dist_id'] == i]
    
    for m in df_best.columns:
            
        df_dist.sort_values(by=[m], inplace = True)
        
        df_best.loc[df_dist.iloc[0].detect_mode, m] += 1
# Out:
# C:\Users\timbr\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df_best['max_loss'] = df_best['max_loss1'] + df_best['max_loss2']
df_best['time_to_recover'] = df_best['time_to_recover1'] + df_best['time_to_recover2']

# %%
df_best[['resloss_sum', 'max_loss', 'time_to_recover']]
# Out:
#                 resloss_sum max_loss time_to_recover
# gradient algo           145       96             110
# model algo full          50      205             191
# model arima l           247      387             380
# model ar l               55      237             242
# dtw mean algo            31      110             110
# detect_dummy              0       21              23

# %% [markdown]
# # Zusammenhang zwischen Signalstärke und Resloss

# %% [markdown]
# # Lerneffekt

# %%
unique_dist = []

for idx, row in df.iterrows():
    for dist in row.dist_name1 + row.dist_name1:
        if dist not in unique_dist:
            unique_dist.append(dist)

# %%
df.columns
# Out:
# Index(['deadtime', 'detect_mode', 'dist_id', 'dist_name', 'exp_id',
#        'model_qual', 'noise_sigma', 'react_mode', 'false_neg_count',
#        'false_pos_count', 'fn_dist', 'fp_dist', 'fp_new', 'max_loss',
#        'overlap', 'resloss_dist', 'resloss_new1', 'resloss_new2',
#        'resloss_sum', 'time_to_detect', 'time_to_recover', 'yexceed+5%',
#        'yexceed_dist', 'signal_power', 'dist_name1', 'dist_name2', 'fn_dist1',
#        'fn_dist2', 'fp_dist1', 'fp_dist2', 'max_loss1', 'max_loss2',
#        'resloss_dist1', 'resloss_dist2', 'time_to_detect1', 'time_to_detect2',
#        'time_to_recover1', 'time_to_recover2', 'yexceed_dist1',
#        'yexceed_dist2', 'signal_power1', 'signal_power2', 'disq', 'r/s'],
#       dtype='object')

# %%
df['r/ex1'] = df['resloss_dist1'] / df['yexceed_dist1']
df['r/ex2'] = df['resloss_dist2'] / df['yexceed_dist2']
# Out:
# C:\Users\timbr\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\timbr\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df[df['resloss_new1'] >= df['resloss_new2']]
# Out:
#     deadtime      detect_mode  dist_id dist_name exp_id model_qual  \
# 1        0.5  model algo full        1       NaN     10          1
# 2        0.5  model algo full       55       NaN    100          1
# 4        0.5  model algo full      342       NaN   1001          1
# 6        0.5       model ar l      342       NaN   1003          1
# 8        0.5    model arima l      342       NaN   1005          1
# ..       ...              ...      ...       ...    ...        ...
# 524      0.5     detect_dummy       48       NaN   2740          1
# 525      0.5     detect_dummy      116       NaN   2741          1
# 526      0.5     detect_dummy       14       NaN   2742          1
# 527      0.5     detect_dummy       83       NaN   2743          1
# 528      0.5     detect_dummy       65       NaN   2744          1
#
#     noise_sigma         react_mode false_neg_count false_pos_count  ...  \
# 1          0.05  move setpoint lim               0               0  ...
# 2          0.05  move setpoint lim               0               0  ...
# 4          0.05  move setpoint lim               1               0  ...
# 6          0.05  move setpoint lim               1               2  ...
# 8          0.05  move setpoint lim               2               0  ...
# ..          ...                ...             ...             ...  ...
# 524        0.05        react_dummy               2               0  ...
# 525        0.05        react_dummy               2               0  ...
# 526        0.05        react_dummy               2               0  ...
# 527        0.05        react_dummy               2               0  ...
# 528        0.05        react_dummy               2               0  ...
#
#     time_to_recover1 time_to_recover2 yexceed_dist1 yexceed_dist2  \
# 1               0.00              0.0      0.000000      0.054859
# 2               6.68              0.0     82.655836      8.079401
# 4               0.00              0.0      0.000000      0.000000
# 6               0.00              0.0      0.000000      0.000000
# 8               0.00              0.0      0.000000      0.000000
# ..               ...              ...           ...           ...
# 524             6.70              0.0      0.000000      0.000000
# 525             6.69              0.0      0.000000      0.000000
# 526             0.00              0.0      0.000000      0.000000
# 527             0.00              0.0      0.000000      0.000000
# 528             6.70              0.0      0.000000      0.000000
#
#     signal_power1  signal_power2  disq          r/s     r/ex1        r/ex2
# 1        0.375000       0.375000   0.0   345.547711       inf  3648.716530
# 2        0.375000       0.369584   0.0   562.896111  0.675993    44.959833
# 4        0.053373       0.026990   0.0  5057.494827       inf          inf
# 6        0.053373       0.026990   0.0  4881.899150       inf          inf
# 8        0.053373       0.026990   0.0  5469.683996       inf          inf
# ..            ...            ...   ...          ...       ...          ...
# 524      0.375000       0.375000   0.0  1239.455907       inf          inf
# 525      0.374491       0.375000   0.0  1116.539878       inf          inf
# 526      0.375000       0.244941   0.0  1018.930356       inf          inf
# 527      0.374864       0.244941   0.0  1016.998967       inf          inf
# 528      0.375000       0.293888   0.0  1468.544834       inf          inf
#
# [1495 rows x 46 columns]

# %%
df[df['resloss_new1'] < df['resloss_new2']]
# Out:
#     deadtime    detect_mode  dist_id dist_name exp_id model_qual noise_sigma  \
# 0        0.5  gradient algo       18       NaN      1          1        0.05
# 3        0.5  model arima l      291       NaN   1000          1        0.05
# 5        0.5  gradient algo      292       NaN   1002          1        0.05
# 7        0.5  model arima l      240       NaN   1004          1        0.05
# 10       0.5  gradient algo      241       NaN   1007          1        0.05
# ..       ...            ...      ...       ...    ...        ...         ...
# 508      0.5   detect_dummy       29       NaN   2725          1        0.05
# 512      0.5   detect_dummy       63       NaN   2729          1        0.05
# 513      0.5   detect_dummy       98       NaN   2730          1        0.05
# 519      0.5   detect_dummy       13       NaN   2735          1        0.05
# 521      0.5   detect_dummy       82       NaN   2737          1        0.05
#
#             react_mode false_neg_count false_pos_count  ... time_to_recover1  \
# 0    move setpoint lim               1               0  ...              0.0
# 3    move setpoint lim               0               0  ...              0.0
# 5    move setpoint lim               1               8  ...              0.0
# 7    move setpoint lim               0               0  ...              6.8
# 10   move setpoint lim               0               1  ...              0.0
# ..                 ...             ...             ...  ...              ...
# 508        react_dummy               2               0  ...              0.0
# 512        react_dummy               2               0  ...              6.5
# 513        react_dummy               2               0  ...              0.0
# 519        react_dummy               2               0  ...              0.0
# 521        react_dummy               2               0  ...              0.0
#
#     time_to_recover2 yexceed_dist1 yexceed_dist2 signal_power1  signal_power2  \
# 0               0.00      5.583336      0.000000      0.375000       0.171189
# 3               0.00      0.124175      0.000000      0.194466       0.053373
# 5               0.00     13.721414     33.678143      0.194466       0.163456
# 7              11.38    992.303881    333.142569      0.363573       0.368016
# 10              7.68     17.954596     41.396204      0.363573       0.363573
# ..               ...           ...           ...           ...            ...
# 508             6.77      0.000000      0.000000      0.375000       0.374491
# 512            28.88      0.000000      0.000000      0.375000       0.333583
# 513             7.10      0.000000      0.000000      0.374549       0.374491
# 519             0.00      0.000000      0.000000      0.375000       0.194466
# 521             0.00      0.000000      0.000000      0.374864       0.194466
#
#      disq          r/s       r/ex1      r/ex2
# 0     0.0   742.100262   10.636265        inf
# 3     0.0  1275.443641  250.504404        inf
# 5     0.0  1131.274254    2.193997  11.128959
# 7     0.0   756.306687    0.045869   1.524239
# 10    0.0   561.712348    2.454576   8.802149
# ..    ...          ...         ...        ...
# 508   0.0  1233.248556         inf        inf
# 512   0.0  2200.480369         inf        inf
# 513   0.0  1241.756415         inf        inf
# 519   0.0  1211.629324         inf        inf
# 521   0.0  1205.072891         inf        inf
#
# [1486 rows x 46 columns]

# %%
df['lerneffekt'] = df['resloss_new1'] - df['resloss_new2']
df.head(50)
# Out:
# C:\Users\timbr\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    deadtime      detect_mode  dist_id dist_name exp_id model_qual noise_sigma  \
# 0       0.5    gradient algo       18       NaN      1          1        0.05
# 1       0.5  model algo full        1       NaN     10          1        0.05
# 2       0.5  model algo full       55       NaN    100          1        0.05
# 3       0.5    model arima l      291       NaN   1000          1        0.05
# 4       0.5  model algo full      342       NaN   1001          1        0.05
# 5       0.5    gradient algo      292       NaN   1002          1        0.05
# 6       0.5       model ar l      342       NaN   1003          1        0.05
# 7       0.5    model arima l      240       NaN   1004          1        0.05
# 8       0.5    model arima l      342       NaN   1005          1        0.05
# 9       0.5  model algo full      292       NaN   1006          1        0.05
# 10      0.5    gradient algo      241       NaN   1007          1        0.05
# 11      0.5    model arima l      325       NaN   1008          1        0.05
# 12      0.5    gradient algo      343       NaN   1009          1        0.05
# 13      0.5       model ar l      106       NaN    101          1        0.05
# 14      0.5    model arima l      274       NaN   1010          1        0.05
# 15      0.5       model ar l      292       NaN   1011          1        0.05
# 16      0.5    gradient algo      326       NaN   1012          1        0.05
# 17      0.5  model algo full      241       NaN   1013          1        0.05
# 18      0.5    gradient algo      275       NaN   1014          1        0.05
# 19      0.5  model algo full      343       NaN   1015          1        0.05
# 20      0.5    model arima l      308       NaN   1016          1        0.05
# 21      0.5    model arima l      257       NaN   1017          1        0.05
# 22      0.5  model algo full      326       NaN   1018          1        0.05
# 23      0.5       model ar l      241       NaN   1019          1        0.05
# 24      0.5  model algo full        4       NaN    102          1        0.05
# 25      0.5    gradient algo      258       NaN   1020          1        0.05
# 26      0.5       model ar l      343       NaN   1021          1        0.05
# 27      0.5    gradient algo      309       NaN   1022          1        0.05
# 28      0.5  model algo full      275       NaN   1023          1        0.05
# 29      0.5    model arima l      292       NaN   1024          1        0.05
# 30      0.5       model ar l      326       NaN   1025          1        0.05
# 31      0.5       model ar l      275       NaN   1026          1        0.05
# 32      0.5  model algo full      309       NaN   1027          1        0.05
# 33      0.5  model algo full      258       NaN   1028          1        0.05
# 34      0.5    gradient algo      293       NaN   1029          1        0.05
# 35      0.5       model ar l       89       NaN    103          1        0.05
# 36      0.5       model ar l      309       NaN   1030          1        0.05
# 37      0.5       model ar l      258       NaN   1031          1        0.05
# 38      0.5    model arima l      343       NaN   1032          1        0.05
# 39      0.5  model algo full      293       NaN   1033          1        0.05
# 40      0.5    model arima l      241       NaN   1034          1        0.05
# 41      0.5    gradient algo      344       NaN   1035          1        0.05
# 42      0.5    model arima l      326       NaN   1036          1        0.05
# 43      0.5       model ar l      293       NaN   1037          1        0.05
# 44      0.5    gradient algo      242       NaN   1038          1        0.05
# 45      0.5    gradient algo      327       NaN   1039          1        0.05
# 46      0.5    model arima l       21       NaN    104          1        0.05
# 47      0.5  model algo full      344       NaN   1040          1        0.05
# 48      0.5    model arima l      275       NaN   1041          1        0.05
# 49      0.5  model algo full      242       NaN   1042          1        0.05
#
#            react_mode false_neg_count false_pos_count  ... time_to_recover2  \
# 0   move setpoint lim               1               0  ...             0.00
# 1   move setpoint lim               0               0  ...             0.00
# 2   move setpoint lim               0               0  ...             0.00
# 3   move setpoint lim               0               0  ...             0.00
# 4   move setpoint lim               1               0  ...             0.00
# 5   move setpoint lim               1               8  ...             0.00
# 6   move setpoint lim               1               2  ...             0.00
# 7   move setpoint lim               0               0  ...            11.38
# 8   move setpoint lim               2               0  ...             0.00
# 9   move setpoint lim               0               0  ...             0.00
# 10  move setpoint lim               0               1  ...             7.68
# 11  move setpoint lim               1               0  ...             0.00
# 12  move setpoint lim               1               0  ...             0.00
# 13  move setpoint lim               0               0  ...             0.00
# 14  move setpoint lim               0               0  ...             0.00
# 15  move setpoint lim               0               1  ...             0.00
# 16  move setpoint lim               1               0  ...             0.00
# 17  move setpoint lim               0               0  ...             7.85
# 18  move setpoint lim               2               1  ...             0.00
# 19  move setpoint lim               1               0  ...             0.00
# 20  move setpoint lim               0               0  ...             0.00
# 21  move setpoint lim               0               0  ...             0.00
# 22  move setpoint lim               1               0  ...             0.00
# 23  move setpoint lim               0               2  ...             7.23
# 24  move setpoint lim               0               0  ...             0.00
# 25  move setpoint lim               1               0  ...             0.00
# 26  move setpoint lim               0               1  ...             0.00
# 27  move setpoint lim               1               0  ...            11.42
# 28  move setpoint lim               0               0  ...             0.00
# 29  move setpoint lim               1               0  ...             0.00
# 30  move setpoint lim               0               1  ...             0.00
# 31  move setpoint lim               0               1  ...             0.00
# 32  move setpoint lim               0               0  ...            11.12
# 33  move setpoint lim               0               0  ...             0.00
# 34  move setpoint lim               1              98  ...            28.65
# 35  move setpoint lim               1               0  ...             0.00
# 36  move setpoint lim               0               2  ...            11.14
# 37  move setpoint lim               0               2  ...             0.00
# 38  move setpoint lim               1               0  ...             0.00
# 39  move setpoint lim               0               0  ...            27.89
# 40  move setpoint lim               0               0  ...             7.22
# 41  move setpoint lim               2               3  ...             0.00
# 42  move setpoint lim               1               0  ...             0.00
# 43  move setpoint lim               0               1  ...            28.13
# 44  move setpoint lim               0               0  ...             0.00
# 45  move setpoint lim               1               0  ...             0.00
# 46  move setpoint lim               0               0  ...             0.00
# 47  move setpoint lim               0               0  ...             0.00
# 48  move setpoint lim               0               0  ...             0.00
# 49  move setpoint lim               0               0  ...             0.00
#
#    yexceed_dist1 yexceed_dist2 signal_power1 signal_power2  disq          r/s  \
# 0       5.583336      0.000000      0.375000      0.171189   0.0   742.100262
# 1       0.000000      0.054859      0.375000      0.375000   0.0   345.547711
# 2      82.655836      8.079401      0.375000      0.369584   0.0   562.896111
# 3       0.124175      0.000000      0.194466      0.053373   0.0  1275.443641
# 4       0.000000      0.000000      0.053373      0.026990   0.0  5057.494827
# 5      13.721414     33.678143      0.194466      0.163456   0.0  1131.274254
# 6       0.000000      0.000000      0.053373      0.026990   0.0  4881.899150
# 7     992.303881    333.142569      0.363573      0.368016   0.0   756.306687
# 8       0.000000      0.000000      0.053373      0.026990   0.0  5469.683996
# 9       0.000000      0.000000      0.194466      0.163456   0.0   888.340475
# 10     17.954596     41.396204      0.363573      0.363573   0.0   561.712348
# 11      0.000000    112.471014      0.053373      0.375000   0.0  1041.910302
# 12      0.000000      8.003509      0.053373      0.239913   0.0  1887.481717
# 13     16.142102     11.101421      0.374328      0.244941   0.0   547.943095
# 14     83.318899    128.845958      0.304985      0.239913   0.0   454.988173
# 15      0.000000      0.000000      0.194466      0.163456   0.0   979.072397
# 16      0.000000      1.545923      0.053373      0.374245   0.0   835.616613
# 17      3.416471      7.960628      0.363573      0.363573   0.0   633.897466
# 18      0.000000     53.325521      0.304985      0.274303   0.0  1063.546385
# 19      0.000000      0.000000      0.053373      0.239913   0.0  1346.286365
# 20     18.629434     44.037653      0.244941      0.369584   0.0   500.229700
# 21     83.318899     96.500991      0.304985      0.374245   0.0   343.393019
# 22      0.000000      0.000000      0.053373      0.374245   0.0   829.874846
# 23      4.241473      9.362519      0.363573      0.363573   0.0   636.896037
# 24      0.005945      0.000000      0.375000      0.374245   0.0   342.925011
# 25      0.000000     24.606675      0.304985      0.374328   0.0   689.803145
# 26      0.000000      0.000000      0.053373      0.239913   0.0  1315.646276
# 27      0.000000    117.549348      0.244941      0.368016   0.0  1017.289984
# 28      0.000000      0.389727      0.304985      0.274303   0.0   463.108795
# 29     72.234819    172.758388      0.194466      0.163456   0.0  1048.252741
# 30      0.000000      0.126362      0.053373      0.374245   0.0   718.060163
# 31      0.000000      2.541823      0.304985      0.274303   0.0   418.832874
# 32      0.000000     71.015859      0.244941      0.368016   0.0   760.508195
# 33      0.000000      9.542755      0.304985      0.374328   0.0   440.263790
# 34      5.991572   2221.098811      0.194466      0.333583   0.0  1961.639059
# 35      0.000000      0.000000      0.374245      0.026990   0.0   867.332510
# 36      0.000000     70.146457      0.244941      0.368016   0.0   789.914549
# 37      0.000000     12.988826      0.304985      0.374328   0.0   433.792876
# 38      0.000000      0.179758      0.053373      0.239913   0.0  1308.145651
# 39      0.000000    444.853771      0.194466      0.333583   0.0  1868.242636
# 40    701.567436    150.788465      0.363573      0.363573   0.0   627.449002
# 41      0.000000     56.596707      0.053373      0.274303   0.0  1528.491879
# 42      0.000000    287.923274      0.053373      0.374245   0.0   820.441974
# 43      0.000000    401.301576      0.194466      0.333583   0.0  1741.155454
# 44     16.168436    157.907406      0.363573      0.304985   0.0   348.169747
# 45      0.000000     24.375841      0.053373      0.374328   0.0   874.784283
# 46     29.190208     59.964838      0.375000      0.239913   0.0   482.573267
# 47      0.000000      0.091921      0.053373      0.274303   0.0  1064.057868
# 48      0.000000     22.332142      0.304985      0.274303   0.0   415.487025
# 49      2.806109     16.155189      0.363573      0.304985   0.0   490.222198
#
#            r/ex1        r/ex2  lerneffekt
# 0   1.063626e+01          inf -143.805882
# 1            inf  3648.716530    0.576328
# 2   6.759930e-01    44.959833   32.444311
# 3   2.505044e+02          inf  -51.989901
# 4            inf          inf   20.865296
# 5   2.193997e+00    11.128959  -13.717881
# 6            inf          inf   13.165454
# 7   4.586917e-02     1.524239 -128.467201
# 8            inf          inf   25.676626
# 9            inf          inf   40.257037
# 10  2.454576e+00     8.802149  -32.292001
# 11           inf     3.772254  -51.728017
# 12           inf    66.465083 -165.831305
# 13  4.254330e+00    24.379797   21.616039
# 14  5.025435e-01     1.599205  -24.861164
# 15           inf          inf   63.531558
# 16           inf   217.155161   38.408081
# 17  1.319282e+01    52.239933  -24.752121
# 18           inf    10.512583  -43.209477
# 19           inf          inf   24.273162
# 20  2.036583e+00     6.118922  -85.139479
# 21  5.025435e-01     1.983104  -10.040746
# 22           inf          inf   41.752450
# 23  1.085309e+01    44.548146  -29.185132
# 24  1.006370e+04          inf    1.975703
# 25           inf    16.787374  107.742783
# 26           inf          inf  -72.407574
# 27           inf     4.935283  -82.270644
# 28           inf   564.645339  -25.576765
# 29  4.152725e-01     1.998138  100.965059
# 30           inf  2250.772332  -11.884842
# 31           inf    77.845504  -17.118630
# 32           inf     6.021765 -231.988551
# 33           inf    26.288135  -61.398787
# 34  5.180083e+00     0.452391 -643.962046
# 35           inf          inf  -17.197015
# 36           inf     6.341706 -226.401267
# 37           inf    19.241601  -66.515981
# 38           inf  2014.996751   17.516382
# 39           inf     2.146042 -651.011653
# 40  6.319035e-02     2.731736  -32.110175
# 41           inf     8.459394 -158.411154
# 42           inf     1.144004   44.493774
# 43           inf     2.215930 -543.699033
# 44  2.768018e+00     1.190679  104.227826
# 45           inf    14.443378  -11.692814
# 46  1.836416e+00     4.054633  -57.097733
# 47           inf  3547.716839  -19.851205
# 48           inf     8.767753  -16.858711
# 49  1.657276e+01    17.408457   99.307735
#
# [50 rows x 47 columns]

# %%
df['lerneffekt'] = df['lerneffekt'].apply(pd.to_numeric, errors='coerce')
df[['detect_mode', 'lerneffekt']].groupby(['detect_mode']).mean()
# Out:
# C:\Users\timbr\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                  lerneffekt
# detect_mode
# detect_dummy      -6.778526
# dtw mean algo    -13.035121
# gradient algo    -36.675712
# model algo full    4.590207
# model ar l        17.488861
# model arima l     13.348329

# %% [markdown]
# # gleiche Gruppe von Störungen

# %%
df_cos = df[df['dist_name1'].str.contains('cosinus') & df['dist_name2'].str.contains('cosinus')]
df_cos[['detect_mode', 'lerneffekt']].groupby(['detect_mode']).mean()
# Out:
#                  lerneffekt
# detect_mode
# detect_dummy       1.256219
# dtw mean algo      1.748979
# gradient algo      2.927322
# model algo full    2.327643
# model ar l         3.795893
# model arima l     14.747852

# %%
df_noisy = df[df['dist_name1'].str.contains('noisycos') & df['dist_name2'].str.contains('noisycos')]
df_noisy[['detect_mode', 'lerneffekt']].groupby(['detect_mode']).mean()
# Out:
#                  lerneffekt
# detect_mode
# detect_dummy       1.461774
# dtw mean algo     -4.079874
# gradient algo      2.846909
# model algo full    3.780092
# model ar l         3.852124
# model arima l     10.686893

# %%
df_chirp = df[df['dist_name1'].str.contains('chirp') & df['dist_name2'].str.contains('chirp')]
df_chirp[['detect_mode', 'lerneffekt']].groupby(['detect_mode']).mean()
# Out:
#                  lerneffekt
# detect_mode
# detect_dummy     -60.541298
# dtw mean algo    -25.043250
# gradient algo    -53.410780
# model algo full  -32.878290
# model ar l       -22.392768
# model arima l    -45.709593

# %%
df_rand = df[df['dist_name1'].str.contains('random') & df['dist_name2'].str.contains('random')]
df_rand[['detect_mode', 'lerneffekt']].groupby(['detect_mode']).mean()
# Out:
#                  lerneffekt
# detect_mode
# detect_dummy       1.874080
# dtw mean algo     -4.184426
# gradient algo    -43.868084
# model algo full    0.854617
# model ar l        14.272757
# model arima l     -0.612008

# %%
df_triag = df[df['dist_name1'].str.contains('triag') & df['dist_name2'].str.contains('triag')]
df_triag[['detect_mode', 'lerneffekt']].groupby(['detect_mode']).mean()
# Out:
#                  lerneffekt
# detect_mode
# detect_dummy       0.608849
# dtw mean algo    -17.131606
# gradient algo   -256.063032
# model algo full   75.359608
# model ar l        74.127593
# model arima l      0.109996
